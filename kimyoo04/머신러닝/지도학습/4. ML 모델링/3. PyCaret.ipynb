# %% [markdown]
# # PyCaret

# %%
# !pip install pycaret

# %%
from pycaret.regression import *

# %%
ixi_model = setup(
                  session_id = 1,
                  data = ixi_train, 
                  target = 'age', 
                  test_data = ixi_test,
                  normalize = True,
                  normalize_method = 'zscore',
                  transformation=True,
                  fold_strategy='stratifiedkfold',
                  use_gpu = True
                  )
