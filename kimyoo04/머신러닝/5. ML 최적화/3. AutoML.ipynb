# %% [markdown]
# # AutoML

# %%
# https://github.com/mljar/mljar-supervised

# %%
# !pip install mljar-supervised
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mljar-supervised
#   Downloading mljar-supervised-0.11.5.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 KB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.22.4)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.3.5)
# Requirement already satisfied: scipy>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.2.1)
# Requirement already satisfied: xgboost>=1.3.3 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.7.4)
# Collecting lightgbm>=3.0.0
#   Downloading lightgbm-3.3.5-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 32.2 MB/s eta 0:00:00
# Collecting catboost>=0.24.4
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.2.0)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (0.8.10)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (3.5.3)
# Collecting dtreeviz>=2.0.0
#   Downloading dtreeviz-2.2.0-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 KB 8.9 MB/s eta 0:00:00
# Collecting shap>=0.36.0
#   Downloading shap-0.41.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 KB 34.7 MB/s eta 0:00:00
# Requirement already satisfied: seaborn>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (0.11.2)
# Requirement already satisfied: wordcloud>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (1.8.2.2)
# Collecting category_encoders>=2.2.2
#   Downloading category_encoders-2.6.0-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 KB 9.9 MB/s eta 0:00:00
# Collecting optuna>=2.7.0
#   Downloading optuna-3.1.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 26.2 MB/s eta 0:00:00
# Collecting scikit-plot==0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: markdown in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (3.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from mljar-supervised) (4.5.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost>=0.24.4->mljar-supervised) (0.10.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost>=0.24.4->mljar-supervised) (1.15.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost>=0.24.4->mljar-supervised) (5.5.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from category_encoders>=2.2.2->mljar-supervised) (0.13.5)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from category_encoders>=2.2.2->mljar-supervised) (0.5.3)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from dtreeviz>=2.0.0->mljar-supervised) (3.6.4)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm>=3.0.0->mljar-supervised) (0.38.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (4.39.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (8.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna>=2.7.0->mljar-supervised) (6.0)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna>=2.7.0->mljar-supervised) (4.65.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna>=2.7.0->mljar-supervised) (1.4.46)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.2-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.2.0->mljar-supervised) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0->mljar-supervised) (3.1.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from shap>=0.36.0->mljar-supervised) (0.56.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from shap>=0.36.0->mljar-supervised) (2.2.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown->mljar-supervised) (6.0.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown->mljar-supervised) (3.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna>=2.7.0->mljar-supervised) (2.0.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->shap>=0.36.0->mljar-supervised) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba->shap>=0.36.0->mljar-supervised) (57.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost>=0.24.4->mljar-supervised) (8.2.2)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest->dtreeviz>=2.0.0->mljar-supervised) (9.1.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from pytest->dtreeviz>=2.0.0->mljar-supervised) (22.2.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.9/dist-packages (from pytest->dtreeviz>=2.0.0->mljar-supervised) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from pytest->dtreeviz>=2.0.0->mljar-supervised) (1.11.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.9/dist-packages (from pytest->dtreeviz>=2.0.0->mljar-supervised) (1.4.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna>=2.7.0->mljar-supervised) (2.1.2)
# Building wheels for collected packages: mljar-supervised
#   Building wheel for mljar-supervised (setup.py) ... done
#   Created wheel for mljar-supervised: filename=mljar_supervised-0.11.5-py3-none-any.whl size=147063 sha256=38c135eb98a825dde079932b4caef83138c17224c6c8dfe0e93c463e68e8db09
#   Stored in directory: /root/.cache/pip/wheels/62/ed/f2/9a70a649613cf977a8b1e39ce373d14290a135fa309c1f1638
# Successfully built mljar-supervised
# Installing collected packages: colour, slicer, Mako, colorlog, cmaes, alembic, shap, scikit-plot, optuna, lightgbm, dtreeviz, catboost, category_encoders, mljar-supervised
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
# Successfully installed Mako-1.2.4 alembic-1.10.2 catboost-1.1.1 category_encoders-2.6.0 cmaes-0.9.1 colorlog-6.7.0 colour-0.1.5 dtreeviz-2.2.0 lightgbm-3.3.5 mljar-supervised-0.11.5 optuna-3.1.0 scikit-plot-0.3.7 shap-0.41.0 slicer-0.0.7

# %% [markdown]
# #### 이진 분류

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from supervised.automl import AutoML

df = pd.read_csv(
    "https://raw.githubusercontent.com/pplonski/datasets-for-start/master/adult/data.csv",
    skipinitialspace=True,
)

x = df[df.columns[:-1]]
y = df["income"]

x_train, x_test, y_train, y_test =\
    train_test_split(x, y, stratify=y, test_size=0.2, random_state=1)

model = AutoML()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
# Out:
# Linear algorithm was disabled.
# AutoML directory: AutoML_1
# The task is binary_classification with evaluation metric logloss
# AutoML will use algorithms: ['Baseline', 'Decision Tree', 'Random Forest', 'Xgboost', 'Neural Network']
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'ensemble']
# * Step simple_algorithms will try to check up to 2 models
# y_true takes value in {'<=50K', '>50K'} and pos_label is not specified: either make y_true take value in {0, 1} or {-1, 1} or pass pos_label explicitly.
# 1_Baseline logloss 0.552923 trained in 0.69 seconds
# y_true takes value in {'<=50K', '>50K'} and pos_label is not specified: either make y_true take value in {0, 1} or {-1, 1} or pass pos_label explicitly.
# 2_DecisionTree logloss 0.367101 trained in 12.62 seconds
# * Step default_algorithms will try to check up to 3 models
# y_true takes value in {'<=50K', '>50K'} and pos_label is not specified: either make y_true take value in {0, 1} or {-1, 1} or pass pos_label explicitly.
# 3_Default_Xgboost logloss 0.279329 trained in 7.11 seconds
# y_true takes value in {'<=50K', '>50K'} and pos_label is not specified: either make y_true take value in {0, 1} or {-1, 1} or pass pos_label explicitly.
# 4_Default_NeuralNetwork logloss 0.324171 trained in 8.41 seconds
# y_true takes value in {'<=50K', '>50K'} and pos_label is not specified: either make y_true take value in {0, 1} or {-1, 1} or pass pos_label explicitly.
# 5_Default_RandomForest logloss 0.338754 trained in 7.19 seconds
# * Step ensemble will try to check up to 1 model
# y_true takes value in {'<=50K', '>50K'} and pos_label is not specified: either make y_true take value in {0, 1} or {-1, 1} or pass pos_label explicitly.
# Ensemble logloss 0.279329 trained in 2.18 seconds
# AutoML fit time: 44.37 seconds
# AutoML best model: 3_Default_Xgboost

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.91      0.92      0.92      6200
#         >50K       0.74      0.71      0.73      1941
#
#     accuracy                           0.87      8141
#    macro avg       0.83      0.82      0.82      8141
# weighted avg       0.87      0.87      0.87      8141

# %% [markdown]
# #### 멀티 클래스 분류

# %%
import pandas as pd 
from sklearn.datasets import load_digits
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from supervised.automl import AutoML

# %%
digits = load_digits()
x = pd.DataFrame(digits.data)
y = digits.target

x_train, x_test, y_train, y_test =\
    train_test_split(x, y, stratify=y, test_size=0.2, random_state=1)

model = AutoML(mode="Perform")
model.fit(x_train, y_train)

y_pred = model.predict_all(x_test)
print(y_pred.head())
print("Test accuracy:", accuracy_score(y_test, y_pred["label"].astype(int)))
# Out:
# AutoML directory: AutoML_2
# The task is multiclass_classification with evaluation metric logloss
# AutoML will use algorithms: ['Linear', 'Random Forest', 'LightGBM', 'Xgboost', 'Neural Network']
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'ensemble']
# * Step simple_algorithms will try to check up to 1 model
# 1_Linear logloss 0.11709 trained in 13.61 seconds (1-sample predict time 0.0707 seconds)
# * Step default_algorithms will try to check up to 4 models
# 2_Default_LightGBM logloss 0.119508 trained in 123.02 seconds (1-sample predict time 0.0469 seconds)
# 3_Default_Xgboost logloss 0.141544 trained in 38.85 seconds (1-sample predict time 0.0522 seconds)
# 4_Default_NeuralNetwork logloss 0.244656 trained in 4.28 seconds (1-sample predict time 0.0681 seconds)
# 5_Default_RandomForest logloss 0.835827 trained in 16.22 seconds (1-sample predict time 0.126 seconds)
# * Step not_so_random will try to check up to 16 models
# 10_LightGBM logloss 0.108165 trained in 49.27 seconds (1-sample predict time 0.0459 seconds)
# 6_Xgboost logloss 0.167263 trained in 58.62 seconds (1-sample predict time 0.0492 seconds)
# 14_RandomForest logloss 0.807765 trained in 14.39 seconds (1-sample predict time 0.1158 seconds)
# 18_NeuralNetwork logloss 0.438477 trained in 5.25 seconds (1-sample predict time 0.0685 seconds)
# 11_LightGBM logloss 0.094231 trained in 32.59 seconds (1-sample predict time 0.0466 seconds)
# 7_Xgboost logloss 0.141853 trained in 47.18 seconds (1-sample predict time 0.0494 seconds)
# 15_RandomForest logloss 0.447175 trained in 24.78 seconds (1-sample predict time 0.1582 seconds)
# 19_NeuralNetwork logloss 0.15857 trained in 6.41 seconds (1-sample predict time 0.0658 seconds)
# 12_LightGBM logloss 0.112702 trained in 96.96 seconds (1-sample predict time 0.0461 seconds)
# 8_Xgboost logloss 0.316154 trained in 33.64 seconds (1-sample predict time 0.0489 seconds)
# 16_RandomForest logloss 1.104381 trained in 9.5 seconds (1-sample predict time 0.0842 seconds)
# 20_NeuralNetwork logloss 0.404874 trained in 7.57 seconds (1-sample predict time 0.0695 seconds)
# 13_LightGBM logloss 0.132 trained in 154.49 seconds (1-sample predict time 0.0482 seconds)
# 9_Xgboost logloss 0.8793 trained in 39.92 seconds (1-sample predict time 0.0488 seconds)
# 17_RandomForest logloss 0.505358 trained in 16.77 seconds (1-sample predict time 0.12 seconds)
# 21_NeuralNetwork logloss 0.35869 trained in 6.86 seconds (1-sample predict time 0.0666 seconds)
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: 36_multiply_28
# Add Golden Feature: 18_ratio_26
# Add Golden Feature: 36_multiply_4
# Add Golden Feature: 52_ratio_36
# Add Golden Feature: 57_sum_2
# Add Golden Feature: 61_ratio_3
# Add Golden Feature: 59_ratio_2
# Add Golden Feature: 61_ratio_34
# Add Golden Feature: 2_ratio_13
# Add Golden Feature: 13_ratio_2
# Created 10 Golden Features in 2.87 seconds.
# 11_LightGBM_GoldenFeatures logloss 0.10056 trained in 37.57 seconds (1-sample predict time 0.0669 seconds)
# 10_LightGBM_GoldenFeatures logloss 0.110747 trained in 57.59 seconds (1-sample predict time 0.0759 seconds)
# 12_LightGBM_GoldenFeatures logloss 0.125254 trained in 103.77 seconds (1-sample predict time 0.0715 seconds)
# * Step insert_random_feature will try to check up to 1 model
# 11_LightGBM_RandomFeature logloss 0.093032 trained in 34.55 seconds (1-sample predict time 0.0477 seconds)
# Drop features ['25', '23', '47', '8', '31', '16', '24', '40', '48', '56', '55', '17', '14', 'random_feature', '11']
# * Step features_selection will try to check up to 4 models
# 11_LightGBM_SelectedFeatures logloss 0.083383 trained in 33.29 seconds (1-sample predict time 0.0425 seconds)
# 3_Default_Xgboost_SelectedFeatures logloss 0.140423 trained in 42.17 seconds (1-sample predict time 0.0445 seconds)
# 19_NeuralNetwork_SelectedFeatures logloss 0.142242 trained in 7.56 seconds (1-sample predict time 0.0638 seconds)
# 15_RandomForest_SelectedFeatures logloss 0.453833 trained in 17.51 seconds (1-sample predict time 0.1186 seconds)
# * Step hill_climbing_1 will try to check up to 10 models
# 22_LightGBM_SelectedFeatures logloss 0.085059 trained in 62.77 seconds (1-sample predict time 0.0413 seconds)
# 23_LightGBM logloss 0.093545 trained in 68.95 seconds (1-sample predict time 0.0439 seconds)
# 24_Xgboost_SelectedFeatures logloss 0.136996 trained in 75.71 seconds (1-sample predict time 0.0464 seconds)
# 25_Xgboost_SelectedFeatures logloss 0.13919 trained in 59.54 seconds (1-sample predict time 0.0481 seconds)
# 26_Xgboost logloss 0.138524 trained in 75.62 seconds (1-sample predict time 0.0488 seconds)
# 27_Xgboost logloss 0.141796 trained in 65.18 seconds (1-sample predict time 0.0506 seconds)
# 28_NeuralNetwork_SelectedFeatures logloss 0.184811 trained in 8.22 seconds (1-sample predict time 0.0636 seconds)
# 29_NeuralNetwork logloss 0.164307 trained in 8.73 seconds (1-sample predict time 0.0656 seconds)
# 30_RandomForest logloss 0.409467 trained in 25.88 seconds (1-sample predict time 0.1588 seconds)
# 31_RandomForest_SelectedFeatures logloss 0.404997 trained in 25.93 seconds (1-sample predict time 0.1552 seconds)
# * Step hill_climbing_2 will try to check up to 9 models
# 32_LightGBM_SelectedFeatures logloss 0.084429 trained in 120.49 seconds (1-sample predict time 0.043 seconds)
# 33_Xgboost_SelectedFeatures logloss 0.127339 trained in 73.85 seconds (1-sample predict time 0.0479 seconds)
# 34_Xgboost logloss 0.132548 trained in 67.13 seconds (1-sample predict time 0.0501 seconds)
# 35_NeuralNetwork_SelectedFeatures logloss 0.315242 trained in 9.56 seconds (1-sample predict time 0.0692 seconds)
# 36_NeuralNetwork logloss 0.3062 trained in 10.09 seconds (1-sample predict time 0.0688 seconds)
# 37_RandomForest_SelectedFeatures logloss 0.361694 trained in 25.83 seconds (1-sample predict time 0.1573 seconds)
# 38_RandomForest_SelectedFeatures logloss 0.448332 trained in 28.11 seconds (1-sample predict time 0.1609 seconds)
# 39_RandomForest logloss 0.365933 trained in 30.26 seconds (1-sample predict time 0.1624 seconds)
# 40_RandomForest logloss 0.444465 trained in 30.94 seconds (1-sample predict time 0.1559 seconds)
# * Step ensemble will try to check up to 1 model
# Ensemble logloss 0.070479 trained in 7.72 seconds (1-sample predict time 0.3913 seconds)
# AutoML fit time: 2096.51 seconds
# AutoML best model: Ensemble
#    prediction_0  prediction_1  prediction_2  prediction_3  prediction_4  \
# 0      0.001328      0.003083      0.006384      0.166817      0.000717
# 1      0.000026      0.000726      0.000058      0.000244      0.000083
# 2      0.000006      0.000006      0.000013      0.999489      0.000006
# 3      0.000011      0.026996      0.000011      0.000020      0.038894
# 4      0.000375      0.001461      0.000282      0.000384      0.009041
#
#    prediction_5  prediction_6  prediction_7  prediction_8  prediction_9  label
# 0      0.006307      0.002034      0.002249      0.145505      0.665576      9
# 1      0.000290      0.000051      0.000020      0.998327      0.000174      8
# 2      0.000018      0.000006      0.000008      0.000076      0.000373      3
# 3      0.000036      0.000020      0.933967      0.000034      0.000011      7
# 4      0.000740      0.000261      0.980113      0.001501      0.005841      7
# Test accuracy: 0.9844444444444445
